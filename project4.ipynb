# %% [markdown]
# # КОММЕНТАРИЙ РЕВЬЮВЕРА 2:
#
# Приветствую тебя еще раз!) Спасибо за то, что доработал проект!
#
# Мои комментарии будут также обозначены разными цветами, но с пометкой 2:
#
#     «КОММЕНТАРИЙ РЕВЬЮВЕРА 2: ... »

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# Андрей, ты доработал критические моменты, молодец! У тебя получился хороший проект, я очень надеюсь, что мои желтые комментарии и зеленые альтернативные подходы помогли взглянуть тебе на некоторые вещи под другим углом и в последующих проектах ты уже будешь все это использовать!) Желаю тебе успехов)
#
# </div>

# %% [markdown]
# # КОММЕНТАРИЙ РЕВЬЮВЕРА
# Привет, Андрей!)
#
# Меня зовут Обидин Андрей, я проверял твой проект. Благодарю тебя за то, что вовремя всё сдал и хорошо поработал!) Мне понравился твой проект, однако есть несколько замечаний и рекомендаций, пожалуйста доработай их. После я смогу принять твою работу!) В конце есть чек-лист
#
# Далее по ходу работы ты сможешь встретить мои комментарии, они будут отмечены разными цветами:
#
# <div class="alert alert-block alert-success">
# Похвала и возможности развития
# </div>
# <div class="alert alert-block alert-warning">
# Некритичные замечания, но стоит обратить внимание
# </div>
# <div class="alert alert-block alert-danger">
# Грубая ошибка, необходимо исправить
# </div>
#
#
# Заранее прошу не удалять мои комментарии, это важно. Если у тебя возникнут вопросы, обозначь их, я с радостью тебе помогу!)
#
# Как вариант, можешь обозначить их так:
# <div class="alert alert-block alert-info">
# <b>КОММЕНТАРИЙ СТУДЕНТА:</b>
# </div>

# %% [markdown]
# # Сборный проект 1
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры.
#
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation).
#
# 🎯 Вам нужно _выявить определяющие успешность игры закономерности_. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании. Перед вами данные до 2016 года.
#
# Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Получилось хорошее интро, можешь даже сделать <a href="https://sebastianraschka.com/Articles/2014_ipython_internal_links.html">кликабельные разделы</a>, чтобы ориентироваться в проекте было еще проще.
#
# </div>

# %% [markdown]
# ## 1. Общая информация о датасете

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
games = pd.read_csv('/datasets/games.csv')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# 16 715 записей

# %%
games.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
games.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16711               LMA Manager 2007     X360           2006.0      Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16713               Spirits & Spells      GBA           2003.0    Platform
# 16714            Winning Post 8 2016      PSV           2016.0  Simulation
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 16710      0.00      0.00      0.01          0.0           NaN        NaN
# 16711      0.00      0.01      0.00          0.0           NaN        NaN
# 16712      0.00      0.00      0.01          0.0           NaN        NaN
# 16713      0.01      0.00      0.00          0.0           NaN        NaN
# 16714      0.00      0.00      0.01          0.0           NaN        NaN
#
#       Rating
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN

# %% [markdown]
# | Признак         | Описание                                    |
# |-----------------|-------------------------------------------|
# | Name            | Название игры                               |
# | Platform        | Платформа                                  |
# | Year_of_Release | Год выпуска                                 |
# | Genre           | Жанр игры                                  |
# | NA_sales        | Продажи в Северной Америке (миллионы долларов)  |
# | EU_sales        | Продажи в Европе (миллионы долларов)           |
# | JP_sales        | Продажи в Японии (миллионы долларов)           |
# | Other_sales     | Продажи в других странах (миллионы долларов)     |
# | Critic_Score    | Оценка критиков (максимум 100)                |
# | User_Score      | Оценка пользователей (максимум 10)             |
# | Rating          | Рейтинг от организации ESRB.                   |

# %%
# Количество игр в датасете
len(games['Name'].unique())
# Out:
# 11560

# %%
# Платформы
games['Platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
# Жанры
games['Genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
# Возрастной рейтинг
games['Rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: Rating, dtype: int64

# %% [markdown]
# ### Количество полных дубликатов и пропусков

# %%
games.duplicated().sum()
# Out:
# 0

# %%
games.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
len(games.query("User_Score == 'tbd'"))
# Out:
# 2424

# %% [markdown]
# ⚠️  Рейтинг пользователей содержит не только явные пропуски, но и пропуски в виде значений `tbd` _(to be defined)_ плейсхолдеры, которые, видимо, предполагалось заполнить позднее или для которых не нашлось данных на момент выгрузки.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Молодец, ты очень даже хорошо осмотрел датафрейм!
#
# </div>

# %% [markdown]
# ## 2. Подготовка данных

# %% [markdown]
# ### Приведем названия признаков к нижнему регистру

# %%
games.columns = [c.lower() for c in list(games.columns)]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Good
#
# </div>

# %% [markdown]
# ### Обработаем пропуски

# %% [markdown]
# Следующие признаки содержат пропуски:
#
# | Признак         | Описание                                       | Количество пропусков |
# |-----------------|----------------------------------------------|-------------------|
# | name            | Название игры                                  | 2                 |
# | genre           | Жанр игры                                     | 2                |
# | year_of_release | Год выпуска                                    | 269              |
# | critic_score    | Оценка критиков (максимум 100)                  | 8578              |
# | user_score      | Оценка пользователей (максимум 10)                | 9 125            |
# | rating          | Рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию. | 6766 |

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Какой ты молодец, что сделал такую табличку!
#
# </div>

# %% [markdown]
# #### Название игры и жанр

# %%
def missing_data_in(col):
    '''
    Возвращает Series с пропусками в указанной колонке
    '''
    return games[games[col].isnull()]

# %%
missing_data_in('name')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# О 2х играх на платформе GEN практически ничего не известно. С этой ошибкой в данных мы ничего не сможем сделать, поэтому от этих "данных" можно избавиться.

# %%
games.drop(missing_data_in('name').index , inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Согласен
#
# </div>

# %% [markdown]
# ---
#
# #### Год выпуска

# %% [markdown]
# 269 пропусков из 16 715 записей – это ~1.6% датасета. Даже если мы не сумеем заполнить эти пропуски, ничего критичного не случится. Однако, все равно посмотрим сначала на данные.

# %%
# Выберем парочку игр без года релиза
missing_data_in('year_of_release').head(2)
# Out:
#                  name platform  year_of_release   genre  na_sales  eu_sales  \
# 183   Madden NFL 2004      PS2              NaN  Sports      4.26      0.26
# 377  FIFA Soccer 2004      PS2              NaN  Sports      0.59      2.36
#
#      jp_sales  other_sales  critic_score user_score rating
# 183      0.01         0.71          94.0        8.5      E
# 377      0.04         0.51          84.0        6.4      E

# %%
# Предположим, что пропуски есть у одной и той же игры на какой-то платформе (ошибка при выгрузке данных)
games.query("name == 'FIFA Soccer 2004'")
# Out:
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 377    FIFA Soccer 2004      PS2              NaN  Sports      0.59      2.36
# 2606   FIFA Soccer 2004       XB           2003.0  Sports      0.24      0.49
# 12029  FIFA Soccer 2004       GC           2003.0  Sports      0.05      0.01
# 13086  FIFA Soccer 2004      GBA           2003.0  Sports      0.04      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 377        0.04         0.51          84.0        6.4      E
# 2606       0.00         0.05          82.0        8.2      E
# 12029      0.00         0.00          83.0        6.2      E
# 13086      0.00         0.00          82.0        7.9      E

# %% [markdown]
# Действительно! Для PS2 нет года релиза. Конечно, может случится и так, что игра для какой-то плафтормы выйдет позже, но в среднем издатели стараются выпускать мультиплатформенные проекты в один год. Поэтому мы можем заполнить подобные пропуски взяв значение из записи другой платформы.

# %%
not_null_values = games[games['year_of_release'].notnull()]

# %%
def fill_year_of_release(row, **kwargs):
    col = 'year_of_release'
    rows = not_null_values[not_null_values['name'] == row['name']]
   
    if len(rows) > 0:
        return rows.iloc[0][col]
    
    return row[col]

# %%
games['year_of_release'] = games.apply(fill_year_of_release, axis=1).astype('Int64')

# %%
len(missing_data_in('year_of_release'))
# Out:
# 146

# %% [markdown]
# 📝 Почти половину пропусков признака "Год выпуска" мы заполнили, но большую часть не смогли. Оставим их.
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Молодец, очень хорошо что ты поработал с пропусками по году!
#
# </div>

# %% [markdown]
# ⚠️ Со следующими пропусками сложнее. Можно попробовать заполнить их после изучения вариативности значений признаков выборочной совокупности, например, для каждой игры выбирать данные по такой же платформе и жанру и брать медиану. Но тогда, скорее всего, мы сдвинем распределение.
#
# #### Оценка критиков
#
# * Максимальное значение равно 100
# * Количество пропусков ~51% датасета
#
# #### Оценка пользователей
#
# * Максимальное значение равно 10
# * Количество пропусков ~55% датасета
#
# #### Рейтинг от организации ESRB
#
# * Количество пропусков ~40% датасета

# %%
# Преобразуем неявные пропуски `tbd` в NaN
tbd = games['user_score'] != 'tbd'
games['user_score'].where(tbd, np.nan, inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Можно было проще, просто использовать to_numeric(errors = 'coerce'), тогда бы тип с object сменился на float, а все неподходящие значение (такие как tbd) поменялись на nan
#
# </div>

# %%
games.isnull().sum()
# Out:
# name                  0
# platform              0
# year_of_release     146
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating             6764
# dtype: int64

# %% [markdown]
# ☝🏻 _Теоретически, даже 50-60% датасета нам должно хватить для дальнейшего анализа и проверки гипотез. Оставим и эти пропуски незаполненными._

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Молодец, что не стал заполнять пропуски по оценкам, это бы исказило всё
#
# </div>

# %% [markdown]
# ### Преобразуйте данные в нужные типы

# %% [markdown]
# | Признак          | Тип данных | Причина замены                                      |
# |-----------------|-----------|---------------------------------------------------|
# | year_of_release | Int64     | Год должен быть целочисленным значением                 |
# | user_score      | float64   | Пользовательские рейтинги должны быть представлены числами |
# | critic_score    | Int64     | Критики выставляют рейтинги целыми числами              |

# %% [markdown]
# ⚠️ Так как столбцы содержат пропуски, переводим в [nullable тип](https://pandas.pydata.org/pandas-docs/stable/user_guide/integer_na.html) `Int64`.

# %%
games['year_of_release'] = games['year_of_release'].astype('Int64')
games['critic_score'] = games['critic_score'].astype('Int64')
games['user_score'] = games['user_score'].astype('float64')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Молодец!
#
# </div>

# %% [markdown]
# ### Суммарные продажи во всех регионах

# %%
games['total_sales'] = games.loc[:,['na_sales', 'eu_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %% [markdown]
# Вывод:
# - Названия колоннок были приведены к нижнему реестру
# - Удалили данные с названием платформы GEN, из-за отстусвия в них информации
# - Пропуски по году выпуска для PS2 были заполнены, исходя из того что релизы как правило происходят в один год
# - Заменили пропуски tbd на NaN
# - Преобразовали данные к нужным типам
# - Создали столбец с суммарными продажами

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
#
# Продажи есть, супер!
# </div>
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Стоит написать вывод
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# Отлично, молодец!
#
# </div>

# %% [markdown]
# ## 3. Исследовательский анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы

# %%
games_per_year = (
    games[['name', 'year_of_release']]
        .drop_duplicates()
        .pivot_table(index='year_of_release', values='name', aggfunc='count')
        .sort_values('year_of_release', ascending=False)
)

# %%
plt.style.use('bmh')

(
    games_per_year
        .plot(figsize=(6, 3), colormap='jet', legend=False, title='Количество игр по годам')
        .set(xlabel='Год релиза', ylabel='Кол-во')
)

plt.show()

# %% [markdown]
# Если предположить, что объем игрового рынка не был таким массовым до выхода консолей типа Sony PlayStation и широкого распространения персональных компьютеров, то нас не будут интересовать данные до середины девяностых. Да и мало кто хочет играть в старые игры, разве что настольгирующие хипстеры. Поэтому можем ограничиться десятилетним промежутком.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Можно было использовать просто гистограмку частот, так бы не пришлось строить сводные
#
# По поводу выводов ты прав, мы видим, что индустрия начинает расти где то с 94-95 года, с 2001-2002 происходит скачок в 2 раза
#
# </div>

# %% [markdown]
# ### Как менялись продажи по платформам

# %%
# Глобальные продажи по платформам
def total_sales_per_platform_for(df):
    return (
        df
            .pivot_table(index='platform', values='total_sales', aggfunc='sum')
            .sort_values('total_sales', ascending=False)
    )

# %%
# Столбчатая диаграмма глобальных продаж
def bar_plot(df):
    (
        df
            .plot(kind='bar', y='total_sales', figsize=(10, 5), legend=False)
            .set(title='Глобальные продажи по игровым платформам',xlabel='Платформа', ylabel='Глобальные продажи')
    )
    plt.show()

# %%
bar_plot(total_sales_per_platform_for(games))

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Молодец!
#
# </div>
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Добавь заголовок
#
# </div>

# %% [markdown]
# Выберем платформы с наибольшими глобальными продажами, например, первые 5 из списка выше и построим распределение по годам.

# %%
top5 = total_sales_per_platform_for(games).head(5)
top5
# Out:
#           total_sales
# platform
# PS2           1595.06
# PS3           1269.94
# X360          1242.18
# Wii           1169.72
# DS             995.01

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Вот они наши лидеры по суммарным продажам!
#
# </div>

# %%
def yearly_total_sales_by_platform(name, df):
    '''
    Глобальные продажи по платформе по годам
    '''
    
    return (
        df
            .query("platform == @name")
            .pivot_table(index='year_of_release', values='total_sales', aggfunc='sum')
            .sort_values('year_of_release', ascending=False)
    )

# %%
# Линейный график глобальных продаж по платформе по годам
for platform in list(top5.index):
    yearly_total_sales_by_platform(platform, games)['total_sales'].plot(figsize=(10, 5), label=platform)
    plt.xlabel("Год релиза", labelpad=10)
    plt.ylabel("Глобальные продажи", labelpad=50)
    plt.title('Глобальные продажи по платформе в зависимости от года')
    plt.legend()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Добавь заголовок на график
#
# </div>

# %% [markdown]
# 📝 Примерно за **10 лет** появляются новые и исчезают старые платформы. Таким образом, мы еще раз убедились, что данные за все периоды нам не понадобятся – достаточно определить _актуальный период в 10 лет_ и смотреть на игры на современных платформах.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ ОТ РЕВЬЮВЕРА:</b>
#
# Для подсчета среднего срока жизни платформы можно было использовать следующий подход: сгруппировать наблюдения по платформам, вывести минимальный и максимальный год релиза, добавить столбец, где будет подсчитана разница между ними. После всего этого дело за малым — посмотреть среднее, а лучше медианы по столбцу разницы.
#
# </div>

# %%
actual_years = (games['year_of_release'] > 2006) & (games['year_of_release'] <= 2016)
actual_games = games.loc[actual_years]

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ ОТ РЕВЬЮВЕРА:</b>
#
# Такой период все же кажется мне слегка широковатым.
#
# Нужно понимать, что на срок жизни платформы приходится как ее взлет, так и падение, которые как правило в большинстве случаев занимают + - одинаковое время. Поэтому можно «средний срок жизни \ 2» — так мы узнаем, сколько уходит на взлет\падение. Далее от 2016 нужно сделать шаг назад на полученное количество лет (срок жизни \ 2) — так мы сможем зацепить хвосты платформ предпоследнего поколения, которые уже теряют свою популярность, но в то же время увидим начинающийся рост новых платформ.
#
#
# </div>

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают

# %% [markdown]
# Глобальные продажи за актуальный период:

# %%
total_sales = total_sales_per_platform_for(actual_games)

# %%
bar_plot(total_sales)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Хоть это и построение графика с помощью функции, думаю стоит добавь заголовок
#
# </div>

# %% [markdown]
# ☝🏻 _какие платформы лидируют по продажам_

# %% [markdown]
# Какие из них растут или падают?

# %%
import warnings
warnings.filterwarnings('ignore')

# список платформ за актуальный период
platforms = list(total_sales.index)

# график из 6 строк
rows = 6
cols = (len(platforms) // rows)
fig, ax = plt.subplots(rows, cols)

# построение графиков продаж по каждой платформе
num = 0
for row in range(rows):
    for col in range(cols):
        platform = platforms[num]
        (
            yearly_total_sales_by_platform(platform, actual_games)['total_sales']
                .plot(ax=ax[row, col], figsize=(20, 20), title=platform)
                .set(xlabel='Год релиза', ylabel='Глобальные продажи')
        )
        num += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам видим, что несмотря на лидирующие продажи за актуальный период, эра большинства платформ подходит к концу и продажи значительно падают. Из перспективных – консоли нового поколения:
#
# * PS4: ~100 млн.
# * XOne: ~40 млн.
#
# Из портативных только 3DS от Nintendo _пока еще_ держится в топе по продажам за 2016 год (около 20 млн).
#
# Объем продаж компьютерных игр с каждым годом все меньше.
#
# 📝 **Рассмотрим детальнее платформы от Sony и Microsoft.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Очень даже хорошо, молодец! Я считаю, что ты хорошо выделил перспективные платформы.
#
# Но не лучше было бы расположить все линейные графики на одной визуализации по аналогии с тем, как ты делал ранее?
#
# </div>

# %% [markdown]
# ### «Ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам

# %%
promising_platforms = ['PS4', 'XOne']

fig, axs = plt.subplots(1, 2, sharey=True)

# построение графиков продаж по каждой платформе
for num, platform in enumerate(promising_platforms):
    df = yearly_total_sales_by_platform(platform, actual_games)
    print(f"Среднее значение глобальных продаж игр для {platform}: {df['total_sales'].mean()}")
    df.boxplot('total_sales', ax=axs[num])
    axs[num].set_title(platform)

plt.tick_params(labelcolor='none', bottom='off')
plt.subplots_adjust(left=0.1)
plt.show()
# Out:
# Среднее значение глобальных продаж игр для PS4: 56.82250000000003
# Среднее значение глобальных продаж игр для XOne: 30.114285714285717

# %% [markdown]
# 📝 Сумма глобальных продаж игр для PS4 примерно в 2 раза больше чем у Xbox One.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Однако мы видим, что медианные продажи по платформам примерно равны
#
# </div>

# %% [markdown]
# ### Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков

# %%
ps4 = actual_games.query("platform == 'PS4'")
xone = actual_games.query("platform == 'XOne'")

# %%
features = ['user_score', 'critic_score', 'total_sales']
ps4[features].corr()
# Out:
#               user_score  critic_score  total_sales
# user_score      1.000000      0.558747    -0.038210
# critic_score    0.558747      1.000000     0.390762
# total_sales    -0.038210      0.390762     1.000000

# %%
xone[features].corr()
# Out:
#               user_score  critic_score  total_sales
# user_score      1.000000      0.472462    -0.061181
# critic_score    0.472462      1.000000     0.417843
# total_sales    -0.061181      0.417843     1.000000

# %%
ps4.plot(x='user_score', y='total_sales', kind='scatter', title='PS4')
xone.plot(x='user_score', y='total_sales', kind='scatter', title='Xbox One', color='green')
plt.show()

# %%
ps4.plot(x='critic_score', y='total_sales', kind='scatter', title='PS4')
xone.plot(x='critic_score', y='total_sales', kind='scatter', title='Xbox One', color='green')
plt.show()

# %% [markdown]
# 📝 Выводы:
#
# * Взаимосвязи между отзывами пользователей и продажами нет;
# * Взаимосвязь между отзывами критиков и продажами существует, однако не слишком большая;
# * Взаимосязь между отзывами критиков и отзывами пользователей существует, чуть большая чем между отзывами критиков и продажами.
#
# Корреляция не говорит о причинно-следственной связи. И хотя по диаграммам рассеяния видим, что чем выше оценки критиков, тем выше продажи игр на обоих платформах, мы не можем утверждать, что высокие оценки критиками приводят к высоким продажам игр, а при покупке игры пользователи больше доверяют критикам, а не коллегам по геймерскому цеху.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Очень хорошая реализация и выводы про корреляцию, молодец!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Стоти сделать обобщение для всех платформ (возможно в принципе посмотри корреляцию по всему датафрейму, а не по конкретным платформам) Сохраняется ли тенденция?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# Общая тенденция с корреляцией сохраняется и для других платформ, однако она варьируется от платформы к платформе.
#
# </div>

# %% [markdown]
# ### Распределение игр по жанрам

# %%
(actual_games
    .pivot_table(index='genre', values='total_sales')
    .sort_values('total_sales', ascending=False)
    .plot(kind='bar', y='total_sales', figsize=(10, 5), legend=False)
    .set(title='Распределение продаж в зависимости от жанра',xlabel='Жанр', ylabel='Глобальные продажи'))

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Добавь заголовок на график
#
# </div>

# %% [markdown]
# 📝 Самыми популярными жанрами ожидаемо являются шутеры, платформеры, а также спортивные игры. Хуже всего продаются стратегии и квесты. Но стоит учитывать региональные продажи, т.к., например, в Японии картина по жанрам может быть совсем другой.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# * посмотри суммарные продажи
#
# * посмотри в принципе кол-во выпускаемых игр по жанрам
#
# P.s. вообще среднее это конечно хорошая метрика, но у нас могут быть выбросы (игры бестселлеры), которые сдвигают ее, поэтому лучше было бы оценивать медиану
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# Жаль, что не посмотрел
#
# </div>

# %% [markdown]
# ## 4. Портрет пользователя каждого региона

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Если ты решишь сокращать актуальный период, чтобы твои исследования были более объективными и актуальными, то портреты регионов могут поменяться
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# В целом, если мы бы подскоратили актуальный период, то лидеры по платформам заменились просто на свои продолжения
#
# </div>

# %% [markdown]
# ### NA / North America

# %%
plt.style.use('seaborn')

# %%
region = 'na_sales'

# %%
def top5_in_region(column):
    return (
        actual_games
            .pivot_table(index=column, values=region, aggfunc='sum')
            .sort_values(region, ascending=False)
            .head(5)
    )

# %%
def sales_pie_by_region(df):
    (
        df
            .plot(kind='pie', y=region, autopct='%1.0f%%', figsize=(10, 5), legend=False)
            .set(ylabel='Продажи')
    )
    plt.show()

# %% [markdown]
# #### Самые популярные платформы (топ-5)

# %%
sales_pie_by_region(top5_in_region('platform'))

# %% [markdown]
# 📝 В США более популярна XBox – Microsoft старается удержаться на родном рынке. Даже Wii немного обходит консоль Sony по продажам.

# %% [markdown]
# #### Самые популярные жанры (топ-5)

# %%
sales_pie_by_region(top5_in_region('genre'))

# %% [markdown]
# 📝 Экшены и шутеры – самые популярные жанры.

# %% [markdown]
# #### Влияет ли рейтинг ESRB на продажи

# %%
sales_pie_by_region(top5_in_region('rating'))

# %% [markdown]
# 📝 Большая доля игр приходится на игры, подходящие для детей, и только 29% продаж на игры для взрослой аудитории (17+)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# В целом портрет Америки очень даже хороший, но вот рейтинги поменяются при корректировке актуального периода
#
# </div>

# %% [markdown]
# ### EU / Europe

# %%
region = 'eu_sales'

# %% [markdown]
# #### Самые популярные платформы (топ-5)

# %%
sales_pie_by_region(top5_in_region('platform'))

# %% [markdown]
# 📝 В Европе более популярна PlayStation, Microsoft в догонящих. Присутствие Wii в Старом Свете еще меньше, чем в США.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Видим, что Европа и Америка в плане платформ очень даже похожи
#
# </div>

# %% [markdown]
# #### Самые популярные жанры (топ-5)

# %%
sales_pie_by_region(top5_in_region('genre'))

# %% [markdown]
# 📝 Экшены и шутеры – все также самые популярные жанры. Надежда на Японию.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# И по жанрам предпочтения Америки и Европы схожи
#
# </div>

# %% [markdown]
# #### Влияет ли рейтинг ESRB на продажи

# %%
sales_pie_by_region(top5_in_region('rating'))

# %% [markdown]
# 📝 В Европе лучше продаются игры для взрослой аудитории: 33% продаж вместо 29%.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Рекомендую пересмотреть рейтинги с актуальным периодом
#
# </div>

# %% [markdown]
# ### JP / Japan

# %%
region = 'jp_sales'

# %% [markdown]
# #### Самые популярные платформы (топ-5)

# %%
sales_pie_by_region(top5_in_region('platform'))

# %% [markdown]
# 📝 В Японии картина продаж кардинально меняется. Японцы много играют на портативных консолях типа Nintento (3)DS, PSP и пр. Здесь мы практически не видим присутствия Xbox в пятерке лидеров.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Воо, картина в Японии уже совсем иная, лидеры платформ сильно отличаются от других регионов (но я рекомендую тебе рассмотреть более актуальный период)
#
# </div>

# %% [markdown]
# #### Самые популярные жанры (топ-5)

# %%
sales_pie_by_region(top5_in_region('genre'))

# %% [markdown]
# 📝 Ролевые игры (JRPG) – самые популярные. О Final Fantasy слышали многие и за пределами Японии, но в целом JRPG – явление довольно уникальное. К слову, экшены отстают по продажам примерно в полтора раза.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Как видим, Япония и тут отличается своими предпочтениями
#
# </div>

# %% [markdown]
# #### Влияет ли рейтинг ESRB на продажи

# %%
sales_pie_by_region(top5_in_region('rating'))

# %% [markdown]
# 📝 В Японии хуже всего продаются игры для взрослой аудитории – всего 17% продаж.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Япония место доброты:)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Мне очень даже понравилось, как ты реализовал анализ портретов потребителей, но рекомендую пересмотреть их с актуальным периодом, возможно ты заметишь явные изменения.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Сформируй вывод пожалуйста, где кратко опиши портрет каждого региона в общих чертах
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# Если бы ты взял более узкий актуальный период, то заметил бы, что Америка и Европа в большей степени любят более жесткие игры, нежели Япония (хотя это слегка прослеживается и у тебя)
#
# </div>

# %% [markdown]
# ### Вывод:
# Для региона США:
#
# - в США три платформы занимаются основной рынок: X360, Wii, PS3; при этом x360 имеет небольшой отрыв в сравнении с другими платформами
# - Жанр экшн наиболее популярен в США в сравнении с остальными, что говорит о том что американцы не любят игры в которые подразумевают длительную прокачку, создание вещей и тд.
# - Основной рынок в США сосредоточен на детей, потому что у них много свободного времени и на них проще всего повлиять, ребенку сложно сказать "нет", но на взрослых рынок тоже ориентируются.
#
# Для европейского региона:
#
# - В Европе лидирующую позицию занимает PS3, но тройка лидеров при этом такая же как и в США
# - Жанр экшн так же популярен в Европе как и в США
# - Рынок так же оринтирован в основном на детей и взрослых
#
# Для японского региона:
#
# - В Японии рынок значительно меняется, аудитория ориентирована на портотивные консоли такие как DS, 3DS
# - В Японии предпочитают RPG-игры, с длительным погружением в игру
# - Доля рынка для взрослых значительно выше по сравнению с детьми

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА 2:</b>
#
# Хорошие выводы, молодец
#
# </div>

# %% [markdown]
# ## 5. Проверка гипотез

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Если ты возьмешь более актуальный период, то будешь больше уверен в статистических тестах
#
# </div>

# %% [markdown]
# Для каждой из приведенных ниже гипотез проверим две (двусторонние) гипотезы о равенстве среднего двух генеральных совокупностей по взятым из них выборкам. Чтобы понять, различаются ли пользовательские рейтинги и значима ли разница между средними значениями, проведем статистические тесты.

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Мы рассматриваем две генеральные сопокупности – игры на разных платформах.
#
# Нулевая гипотеза H₀:
#
# > Средние пользовательские рейтинги платформ Xbox One и PC **одинаковые**.
#
# Исходя из H₀ формулируем альтернативную гипотезу H₁:
#
# > Средние пользовательские рейтинги платформ Xbox One и PC **различаются**.

# %% [markdown]
# _Пороговое значение alpha (критический уровень статистической значимости) зададим равным 2.5%._ На это есть 2 причины:
#
# 1. Большое количество пропусков в датасете.
# 2. Microsoft в последнее время активно развивает геймерские возможности в Windows.

# %%
alpha = .025

# %%
pc = actual_games.query("platform == 'PC'")

results = st.ttest_ind(
    xone['user_score'],
    pc['user_score'],
    equal_var=False,  # Welch’s t-test, который не предполагает равенство дисперсий
    nan_policy='omit' # игнорируем пропуски
)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.029951657643345574
# Не получилось отвергнуть нулевую гипотезу

# %%
pc['user_score'].mean()
# Out:
# 6.770790378006873

# %%
xone['user_score'].mean()
# Out:
# 6.508839779005524

# %% [markdown]
# p-value получили равным ~3%. Если бы рейтинги пользователей НЕ отличались (наша нулевая гипотеза), то те различия, что мы фактически видим, могли бы получиться случайно лишь в 3% случаев. Это весьма маленькая вероятность. Таким образом, различия довольно высокие для предположения равенства рейтингов. Но так как мы задали жесткий уровень значимости (0.025), то говорим, что тем не менее не будем отклонять гипотезу, но со стандартным уровнем в 0.05 мы бы ее уже отвергли.
#
# Гипотеза `Средние пользовательские рейтинги платформ Xbox One и PC одинаковые` **подтвердилась**.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# * гипотезы сформулированы верно
#
# * тест корректен, мы не можем отклонить Но
#
# P.s. я бы рекомендовал рассмотреть более узкий актуальный период, тогда мы будем более уверены в объективности наших тестов
#
# * отталкиваясь от вышесказанного, твой вывод чуть поменяется и станет более твердым, в плане того, что вероятнее всего наше п-значения ощутимо повысится
#
# </div>

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action и Sports разные
#
# Мы рассматриваем две генеральные сопокупности – игры разных жанров.
#
# Нулевая гипотеза H₀:
#
# > Средние пользовательские рейтинги жанров Action и Sports **одинаковые**.
#
# Исходя из H₀ формулируем альтернативную гипотезу H₁:
#
# > Средние пользовательские рейтинги жанров Action и Sports **различаются**.
#
# _Пороговое значение alpha (критический уровень статистической значимости) зададим равным 5%._

# %%
alpha = .05

# %%
action = actual_games.query("genre == 'Action'")
sports = actual_games.query("genre == 'Sports'")

results = st.ttest_ind(
    action['user_score'],
    sports['user_score'],
    nan_policy='omit' # игнорируем пропуски
)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 2.648261415089771e-12
# Отвергаем нулевую гипотезу

# %% [markdown]
# Средние пользовательские рейтинги различаются, и практически нулевая вероятность говорит о том, что случайно получить такое отличие в значениях практически не получится.
#
# Гипотеза `Средние пользовательские рейтинги жанров Action и Sports разные` **подтвердилась**.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# * гипотезы сформулированы верно
#
# * тест корректен, мы отклоняем Но
#
# * вывод хороший, но....(см.далее)
#
# </div>
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Очень режут слух слова «подтверждаем \ принимаем» Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# </div>

# %% [markdown]
# ## 6. Общий вывод

# %% [markdown]
# Тезисы:
#
# * Платформы появляются и умирают в течение 10 лет.
# * Наиболее популярные на данный момент платформы – это Sony PlayStation 4 и Xbox One. Они появились пару лет назад и имеют потенциал роста.
# * В США и Европе лучше всего продаются шутеры и экшены.
# * Япония – отдельный рынок с уклоном в портативные консоли и ролевые игры.
# * Больше всего продаж приходятся на игры, разрешенные для детей.
#
# Обе сформулированные гипотезы подтвердились:
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# * Средние пользовательские рейтинги жанров Action и Sports разные.
#
# ---
#
# 💡 Стоит помнить, что у каждой консоли есть эксклюзивы, из-за которых покупают ту или иную консоль. Кроме того, есть мультиплатформенные блокбастеры с огромными продажами, которые могут сделать определенный жанр в среднем прибыльным. При желании можно убрать подобные "выбросы" и посмотреть на выборочные совокупности без них.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# * опять же, мы ничего не принимаем и не подтверждаем
#
# * рекомендую дополнить список платформ 3DS, она все же довольно популярна в отдельных регионах (таких как Япония)
#
# * напиши что нибудь про корреляцию
# </div>

# %% [markdown]
# ### **Чек-лист по заданиям**
#
# - [x]  Открыты все файлы
# - [x]  Файлы изучены (выведены первые строки, метод info())
# - [x]  Заменены названия столбцов
# - [x]  Данные приведены к нужным типам
# - [x]  Обработаны пропуски
# - [x]  Выполнено задание: Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - [x]  Выполнено задание: Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. Найдите популярные в прошлом платформы, у которых сейчас продажи на нуле. За какой характерный период появляются новые и исчезают старые платформы?
# - [x]  Выполнено задание: Определите, данные за какой период нужно взять, чтобы исключить значимое искажение распределения по платформам в 2016 году.
# - [x]  Выполнено задание: Далее работайте только с данными, которые вы определили. Не учитывайте данные за предыдущие годы.
# - [x]  Выполнено задание: Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - [x]  Выполнено задание: Постройте график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат.
# - [x]  Выполнено задание: Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы и соотнесите их с продажами игр на других платформах.
# - [x]  Выполнено задание: Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
# - [x]  Составлен портрет пользователя *NA,*
# - [x]  Составлен портрет пользователя *EU*
# - [x]  Составлен портрет пользователя  *JP*
# - [x]  Проверена гипотеза: "Средние пользовательские рейтинги платформ *Xbox One* и *PC* одинаковые;"
# - [x]  Проверена гипотеза: "Средние пользовательские рейтинги жанров *Action* (англ. «действие») и *Sports* (англ. «виды спорта») разные."
# - [x]  Есть пояснения к проверке гипотез: "как вы формулировали нулевую и альтернативную гипотезы"
# - [x]  Есть пояснения к проверке гипотез: "какой критерий использовали для проверки гипотез и почему"
# - [x]  В каждом этапе есть выводы
# - [x]  Есть общий вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>КОММЕНТАРИЙ РЕВЬЮВЕРА:</b>
#
# Андрей, у тебя очень даже хороший проект, есть всего несколько моментов на правку!)
# </div>
